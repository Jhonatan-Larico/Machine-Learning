# %% [markdown]
# ## Importando librerias

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
from sklearn.model_selection import train_test_split

# %matplotlib notebook

# %%
# ============= Part 1: Visualizando los datos =============
df = pd.read_csv("./StudentsPerformance.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ## Visualizando datos

# %%
m = 1000
X = np.array(df.iloc[:,6])
X = X.reshape(m,1)
y = np.array(df.iloc[:,7])
y = y.reshape(m,1)

# %%
fig1 = plt.figure(figsize=(5,4),dpi=100)
plt.plot(  X,y ,'rx',label="Training data" )
plt.xlabel("Reading score")
plt.ylabel('Writing score ')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">

# %% [markdown]
# ## Funciones a utilizar

# %%
def plot():
    # ============= Part 3: Visualizing J(theta_0, theta_1) =============
    # Grid over which we will calculate J
    #from mpl_toolkits import mplot3d

    #fig = plt.figure(figsize=(8,6))
    #ax3d = plt.axes(projection="3d")

    theta0_vals = np.linspace(-10, 10, 100)
    theta1_vals = np.linspace(-4, 4, 100)

    # initialize J_vals to a matrix of 0's
    J_vals = np.zeros((len(theta0_vals), len(theta1_vals)))

    # Fill out J_vals
    for i in range(len(theta0_vals)):
        for j in range(len(theta1_vals)):
            t = np.array([ [theta0_vals[i]], [theta1_vals[j]]])        
            J_vals[i,j] = computeCost(X_norm, y_norm, t)
        
    # Because of the way meshgrids work in the surf command, we need to
    # transpose J_vals before calling surf, or else the axes will be flipped

    J_vals = np.transpose(J_vals)

    #theta0_vals,theta1_vals = np.meshgrid(theta0_vals,theta1_vals)
    #ax3d.plot_surface(theta0_vals, theta1_vals, J_vals,cmap='plasma')

    #ax3d.set_title('Cost Function J(0)')
    #ax3d.set_xlabel('$0_{0}$')
    #ax3d.set_ylabel('$0_{1}$')
    #ax3d.set_zlabel('$J(0)$')

    #Contour plot
# Plot J_vals as 15 contours spaced logarithmically between 0.01 and 100

    fig = plt.figure()
    ax = fig.add_subplot(111)
    cs = ax.contour(theta0_vals,theta1_vals,J_vals, np.logspace(-2, 3, 20),colors = "b")
    plt.ylabel('$0_{1}$')
    plt.xlabel('$0_{0}$')

    #plt.plot(theta[0],theta[1]  ,'rx')

# %%
def gradientDesccent(X,y,theta,alpha,num_iters):
    m =len(y)
    J_history  = np.zeros((num_iters,1))
    plot()
    for ite in range(num_iters):
        theta = theta  - (alpha/m)* np.transpose(X).dot(X.dot(theta)-y) 
        J_history[ite] = computeCost(X,y,theta)
        #print(J_history)
        
        if ite % 50 == 0:
            plt.plot(theta[0],theta[1]  ,'rx')

        
    return (J_history,theta)

# %%
def computeCost(X,y,theta):
    m = len(y)
    J = 0
    
    H = X.dot(theta)
    J = np.square(H - y)
    J = np.sum(J)/(2*m)
    return J

# %%
# Scale features and set them to zero mean
def featureNormalize(X):
    X_norm = X
    mu = np.zeros( (1, np.size(X, 1)) ) # tamaño 1x2
    sigma = np.zeros((1, np.size(X, 1) )) # tamaño 1x2
    m = len(X)
    
    mu = np.mean(X,axis=0)
    sigma = np.sum((X - mu)**2,axis=0 )/(m-1)
    sigma = np.sqrt(sigma)

    X_norm = (X - mu )/ sigma;
    return X_norm

# %% [markdown]
# ## Entrenando el modelo

# %%
# Normalizar los datos
X_norm = featureNormalize(X)
y_norm = featureNormalize(y)

#Agregamos una fila de unos de 1xm a la matriz X_norm
X_norm = X_norm.T
ones = np.ones((1,m)) 
X_plus_one = np.concatenate((ones,X_norm))
X_norm = X_plus_one.transpose()

# Divide los datos en entrenamiento y prueba
X_train, X_test , y_train , y_test =train_test_split(X_norm,y_norm,test_size=0.2)

# %%
# Configuraciones del descenso del gradiente
theta_inicial = np.array([10,0]).reshape(2,1)
iterations = 1400
alpha = 0.01
# Obtenemos los parametros theta y el historial de la funcion de coste
J_history,theta = gradientDesccent(X_train,y_train,theta_inicial,alpha,iterations)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
# Plot the convergence graph
fig2 = plt.figure(figsize=(5,4),dpi=80)


plt.plot(np.linspace(1,iterations,iterations),J_history,'r')
plt.xlabel(" Number of iterations ")
plt.ylabel('Cost J')

#Display gradient descent's result
print('Theta computed from gradient descent: \n');
# Out:
# <img src="data:image/png;base64,..." width="399.9999913302337">
# Theta computed from gradient descent:

# %%
XX= X.T # resize the vector  
ones = np.ones((1,m)) 
X_plus_one = np.concatenate((ones,XX))# concatenates ones  
XA = X_plus_one.transpose()

# %%
# Plot the linear fit
fig2 = plt.figure(figsize=(5,4),dpi=80)

plt.plot(  X,y ,'rx',label="Training data" )
plt.plot(XA[:,1] ,XA.dot(theta),label=",Linear regression" )

plt.xlabel("Population of City in 10,000s")
plt.ylabel('Profit in $10,000s')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="399.9999913302337">

# %%
def plot_gradient():
    fig = plt.figure(figsize=(8,6))
    ax3d = plt.axes(projection="3d")

    theta0_vals = np.linspace(-10, 10, 100)
    theta1_vals = np.linspace(-4, 4, 100)

    # initialize J_vals to a matrix of 0's
    J_vals = np.zeros((len(theta0_vals), len(theta1_vals)))

    # Fill out J_vals
    for i in range(len(theta0_vals)):
        for j in range(len(theta1_vals)):
            t = np.array([ [theta0_vals[i]], [theta1_vals[j]]])        
            J_vals[i,j] = computeCost(X_norm, y_norm, t)
        
    # Because of the way meshgrids work in the surf command, we need to
    # transpose J_vals before calling surf, or else the axes will be flipped

    #J_vals = np.transpose(J_vals)
    theta0_vals,theta1_vals = np.meshgrid(theta0_vals,theta1_vals)


    ax3d.plot_surface(theta0_vals, theta1_vals, J_vals,cmap='plasma')

    #ax3d.set_title('Cost Function J(0)')
    #ax3d.set_xlabel('$0_{0}$')
    #ax3d.set_ylabel('$0_{1}$')
    #ax3d.set_zlabel('$J(0)$')

# %%
plot_gradient()
# Out:
# <div id='2d831545-bb18-4bd7-99fd-5e4bddd1028c'></div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-7f4c81a137fd> in <module>
# ----> 1 plot_gradient()
#
# <ipython-input-35-645826255a52> in plot_gradient()
#       6     theta1_vals = np.linspace(-4, 4, 100)
#       7     theta0_vals,theta1_vals = np.meshgrid(theta0_vals,theta1_vals)
# ----> 8     t = np.array([theta0_vals],[theta1_vals])
#       9     gradient  = computeCost(X_norm,y_norm,t)
#      10
#
# TypeError: Field elements must be 2- or 3-tuples, got 'array([[-4.        , -4.        , -4.        , ..., -4.        ,
#         -4.        , -4.        ],
#        [-3.91919192, -3.91919192, -3.91919192, ..., -3.91919192,
#         -3.91919192, -3.91919192],
#        [-3.83838384, -3.83838384, -3.83838384, ..., -3.83838384,
#         -3.83838384, -3.83838384],
#        ...,
#        [ 3.83838384,  3.83838384,  3.83838384, ...,  3.83838384,
#          3.83838384,  3.83838384],
#        [ 3.91919192,  3.91919192,  3.91919192, ...,  3.91919192,
#          3.91919192,  3.91919192],
#        [ 4.        ,  4.        ,  4.        , ...,  4.        ,
#          4.        ,  4.        ]])'

# %%
theta0_vals = np.linspace(-10,10,100).reshape(100,1)
theta1_vals = np.linspace(-4,4,100).reshape(100,1)
theta_vals = np.concatenate((theta0_vals,theta1_vals),axis = 1   )
theta_vals = theta_vals.T

for i in range(len(theta0_vals)):
        for j in range(len(theta1_vals)):
            t = np.array([ [theta0_vals[i]], [theta1_vals[j]]])        
            J_vals[i,j] = computeCost(X_norm, y_norm, t)
gradient  = computeCost(X_norm,y_norm,theta_vals)
#theta0_vals,theta1_vals = np.meshgrid(theta0_vals,theta1_vals)

# %%
gradient
# Out:
# 2022.0685185185189
